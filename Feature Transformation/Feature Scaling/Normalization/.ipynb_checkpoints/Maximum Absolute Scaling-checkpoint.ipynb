# %%
import pandas as pd
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MaxAbsScaler

# %%
df = pd.read_csv('wine_data.csv',header=None,usecols=[0,1,2])
df.columns=['Class label', 'Alcohol', 'Malic acid']

# %%
df.head()
# Out:
#    Class label  Alcohol  Malic acid
# 0            1    14.23        1.71
# 1            1    13.20        1.78
# 2            1    13.16        2.36
# 3            1    14.37        1.95
# 4            1    13.24        2.59

# %%
X_train, X_test, y_train, y_test = train_test_split(
df.drop('Class label', axis=1), df['Class label'], test_size=0.3,
random_state=0)

# %%
scaler = MaxAbsScaler()
scaler.fit(X_train)
# Out:
# MaxAbsScaler()

# %%
X_train_scaled = scaler.transform(X_train)
X_test_scaled = scaler.transform(X_test)

# %%
X_train_scaled
# Out:
# array([[0.92949153, 0.32920354],
#        [0.82847458, 0.22831858],
#        [0.89966102, 0.75752212],
#        [0.89220339, 0.63185841],
#        [0.93966102, 0.26725664],
#        [0.87118644, 0.57876106],
#        [0.93830508, 0.72920354],
#        [0.90169492, 0.30442478],
#        [0.88474576, 0.68318584],
#        [0.84813559, 0.21946903],
#        [0.83322034, 0.24955752],
#        [0.86576271, 0.60707965],
#        [0.87864407, 0.61061947],
#        [0.92677966, 0.22123894],
#        [0.89220339, 0.41769912],
#        [0.83864407, 0.16637168],
#        [0.84542373, 0.26902655],
#        [0.80067797, 0.37522124],
#        [0.89762712, 0.70442478],
#        [0.9559322 , 0.38230088],
#        [0.78711864, 0.23893805],
#        [0.88067797, 0.29557522],
#        [0.86576271, 0.42300885],
#        [0.91389831, 0.29557522],
#        [0.77694915, 0.6619469 ],
#        [0.81830508, 0.38230088],
#        [0.80135593, 0.26017699],
#        [0.91186441, 0.65486726],
#        [0.82711864, 0.53628319],
#        [0.88474576, 0.30619469],
#        [0.89288136, 0.91858407],
#        [0.81898305, 0.23539823],
#        [0.82508475, 0.25663717],
#        [0.8420339 , 0.7840708 ],
#        [0.80474576, 0.76283186],
#        [0.82779661, 0.21061947],
#        [0.94508475, 0.30619469],
#        [0.9559322 , 0.35752212],
#        [0.85898305, 0.17345133],
#        [1.        , 0.30619469],
#        [0.83050847, 0.83539823],
#        [0.87118644, 0.28318584],
#        [0.93084746, 0.77168142],
#        [0.95322034, 0.28849558],
#        [0.9240678 , 0.32035398],
#        [0.8359322 , 0.17522124],
#        [0.93694915, 0.30973451],
#        [0.81898305, 0.36814159],
#        [0.88338983, 0.15929204],
#        [0.97423729, 0.34513274],
#        [0.89288136, 0.45840708],
#        [0.86237288, 0.30973451],
#        [0.97559322, 0.33097345],
#        [0.90440678, 0.16637168],
#        [0.79050847, 0.33274336],
#        [0.80271186, 0.15752212],
#        [0.87186441, 0.23893805],
#        [0.93220339, 0.30619469],
#        [0.84949153, 0.97522124],
#        [0.88881356, 0.33628319],
#        [0.97491525, 0.33097345],
#        [0.96474576, 0.30265487],
#        [0.81355932, 0.26725664],
#        [0.89694915, 0.5840708 ],
#        [0.97491525, 0.63539823],
#        [0.95728814, 0.2619469 ],
#        [0.81355932, 0.60707965],
#        [0.83661017, 0.43362832],
#        [0.91389831, 0.32035398],
#        [0.90101695, 0.34867257],
#        [0.90915254, 0.67964602],
#        [0.92949153, 1.        ],
#        [0.83864407, 0.21415929],
#        [0.89491525, 0.31504425],
#        [0.77627119, 0.42477876],
#        [0.92338983, 0.87610619],
#        [0.94101695, 0.33451327],
#        [0.8420339 , 0.45132743],
#        [0.86847458, 0.40884956],
#        [0.85288136, 0.22831858],
#        [0.93762712, 0.27787611],
#        [0.88610169, 0.26548673],
#        [0.86101695, 0.62831858],
#        [0.93355932, 0.33628319],
#        [0.87050847, 0.52389381],
#        [0.83864407, 0.28849558],
#        [0.9159322 , 0.31858407],
#        [0.94033898, 0.33628319],
#        [0.81898305, 0.2460177 ],
#        [0.92067797, 0.29380531],
#        [0.88677966, 0.69026549],
#        [0.79932203, 0.37699115],
#        [0.8440678 , 0.53628319],
#        [0.92745763, 0.32389381],
#        [0.91661017, 0.56106195],
#        [0.91525424, 0.55221239],
#        [0.87254237, 0.8159292 ],
#        [0.95050847, 0.29734513],
#        [0.83322034, 0.56106195],
#        [0.81898305, 0.2       ],
#        [0.86101695, 0.68495575],
#        [0.74779661, 0.26725664],
#        [0.90305085, 0.57345133],
#        [0.9579661 , 0.72566372],
#        [0.91457627, 0.29380531],
#        [0.80271186, 0.51150442],
#        [0.88474576, 0.36283186],
#        [0.86237288, 0.32035398],
#        [0.86915254, 0.59646018],
#        [0.90847458, 0.81415929],
#        [0.9640678 , 0.70619469],
#        [0.93016949, 0.25309735],
#        [0.87661017, 0.49734513],
#        [0.78915254, 0.36460177],
#        [0.83322034, 0.28495575],
#        [0.78983051, 0.29557522],
#        [0.90033898, 0.29026549],
#        [0.87661017, 0.67256637],
#        [0.93966102, 0.23893805],
#        [0.80135593, 0.30442478],
#        [0.83864407, 0.20707965],
#        [0.8420339 , 0.28495575],
#        [0.94237288, 0.29734513],
#        [0.96      , 0.44424779]])
