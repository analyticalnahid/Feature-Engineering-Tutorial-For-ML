# %%
import pandas as pd
from sklearn.datasets import load_wine
from sklearn.feature_selection import VarianceThreshold

# %%
data = load_wine()
df = pd.DataFrame(data.data, columns = data.feature_names)
df["target"] = data.target
# https://www.kaggle.com/c/santander-customer-satisfaction/data?select=train.csv

# %%
data.target_names
# Out:
# array(['class_0', 'class_1', 'class_2'], dtype='<U7')

# %%
data.feature_names
# Out:
# ['alcohol',
#  'malic_acid',
#  'ash',
#  'alcalinity_of_ash',
#  'magnesium',
#  'total_phenols',
#  'flavanoids',
#  'nonflavanoid_phenols',
#  'proanthocyanins',
#  'color_intensity',
#  'hue',
#  'od280/od315_of_diluted_wines',
#  'proline']

# %%
df.shape
# Out:
# (178, 14)

# %%
df.head()
# Out:
#    alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 0    14.23        1.71  2.43               15.6      127.0           2.80
# 1    13.20        1.78  2.14               11.2      100.0           2.65
# 2    13.16        2.36  2.67               18.6      101.0           2.80
# 3    14.37        1.95  2.50               16.8      113.0           3.85
# 4    13.24        2.59  2.87               21.0      118.0           2.80
#
#    flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 0        3.06                  0.28             2.29             5.64  1.04
# 1        2.76                  0.26             1.28             4.38  1.05
# 2        3.24                  0.30             2.81             5.68  1.03
# 3        3.49                  0.24             2.18             7.80  0.86
# 4        2.69                  0.39             1.82             4.32  1.04
#
#    od280/od315_of_diluted_wines  proline  target
# 0                          3.92   1065.0       0
# 1                          3.40   1050.0       0
# 2                          3.17   1185.0       0
# 3                          3.45   1480.0       0
# 4                          2.93    735.0       0

# %%
df.describe()
# Out:
#           alcohol  malic_acid         ash  alcalinity_of_ash   magnesium  \
# count  178.000000  178.000000  178.000000         178.000000  178.000000
# mean    13.000618    2.336348    2.366517          19.494944   99.741573
# std      0.811827    1.117146    0.274344           3.339564   14.282484
# min     11.030000    0.740000    1.360000          10.600000   70.000000
# 25%     12.362500    1.602500    2.210000          17.200000   88.000000
# 50%     13.050000    1.865000    2.360000          19.500000   98.000000
# 75%     13.677500    3.082500    2.557500          21.500000  107.000000
# max     14.830000    5.800000    3.230000          30.000000  162.000000
#
#        total_phenols  flavanoids  nonflavanoid_phenols  proanthocyanins  \
# count     178.000000  178.000000            178.000000       178.000000
# mean        2.295112    2.029270              0.361854         1.590899
# std         0.625851    0.998859              0.124453         0.572359
# min         0.980000    0.340000              0.130000         0.410000
# 25%         1.742500    1.205000              0.270000         1.250000
# 50%         2.355000    2.135000              0.340000         1.555000
# 75%         2.800000    2.875000              0.437500         1.950000
# max         3.880000    5.080000              0.660000         3.580000
#
#        color_intensity         hue  od280/od315_of_diluted_wines      proline  \
# count       178.000000  178.000000                    178.000000   178.000000
# mean          5.058090    0.957449                      2.611685   746.893258
# std           2.318286    0.228572                      0.709990   314.907474
# min           1.280000    0.480000                      1.270000   278.000000
# 25%           3.220000    0.782500                      1.937500   500.500000
# 50%           4.690000    0.965000                      2.780000   673.500000
# 75%           6.200000    1.120000                      3.170000   985.000000
# max          13.000000    1.710000                      4.000000  1680.000000
#
#            target
# count  178.000000
# mean     0.938202
# std      0.775035
# min      0.000000
# 25%      0.000000
# 50%      1.000000
# 75%      2.000000
# max      2.000000

# %%
X=df.drop(labels=['target'], axis=1)
y=df['target']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.3,random_state=0)

X_train.shape, X_test.shape
# Out:
# ((124, 13), (54, 13))

# %%
X_train.head()
# Out:
#      alcohol  malic_acid   ash  alcalinity_of_ash  magnesium  total_phenols  \
# 22     13.71        1.86  2.36               16.6      101.0           2.61
# 108    12.22        1.29  1.94               19.0       92.0           2.36
# 175    13.27        4.28  2.26               20.0      120.0           1.59
# 145    13.16        3.57  2.15               21.0      102.0           1.50
# 71     13.86        1.51  2.67               25.0       86.0           2.95
#
#      flavanoids  nonflavanoid_phenols  proanthocyanins  color_intensity   hue  \
# 22         2.88                  0.27             1.69             3.80  1.11
# 108        2.04                  0.39             2.08             2.70  0.86
# 175        0.69                  0.43             1.35            10.20  0.59
# 145        0.55                  0.43             1.30             4.00  0.60
# 71         2.86                  0.21             1.87             3.38  1.36
#
#      od280/od315_of_diluted_wines  proline
# 22                           4.00   1035.0
# 108                          3.02    312.0
# 175                          1.56    835.0
# 145                          1.68    830.0
# 71                           3.16    410.0

# %% [markdown]
# ## Removing Constant Features

# %%
var_thres=VarianceThreshold(threshold=1)
var_thres.fit(X_train)
# Out:
# VarianceThreshold(threshold=1)

# %%
### Finding non constant features
sum(var_thres.get_support())
# Out:
# 5

# %%
constant_columns = [column for column in X_train.columns
                    if column not in X_train.columns[var_thres.get_support()]]

print(len(constant_columns))
# Out:
# 8

# %%
for column in constant_columns:
    print(column)
# Out:
# alcohol
# ash
# total_phenols
# flavanoids
# nonflavanoid_phenols
# proanthocyanins
# hue
# od280/od315_of_diluted_wines

# %%
X_train.drop(constant_columns,axis=1)
# Out:
#      malic_acid  alcalinity_of_ash  magnesium  color_intensity  proline
# 22         1.86               16.6      101.0             3.80   1035.0
# 108        1.29               19.0       92.0             2.70    312.0
# 175        4.28               20.0      120.0            10.20    835.0
# 145        3.57               21.0      102.0             4.00    830.0
# 71         1.51               25.0       86.0             3.38    410.0
# ..          ...                ...        ...              ...      ...
# 103        1.72               19.5       86.0             2.06    415.0
# 67         1.17               19.6       78.0             4.68    510.0
# 117        1.61               22.5      108.0             2.06    345.0
# 47         1.68               16.0      101.0             6.10    985.0
# 172        2.51               20.0       91.0             9.70    660.0
#
# [124 rows x 5 columns]

# %% [markdown]
# ## Removing Duplicated Features

# %%
# transpose the feature matrice
train_features_T = X_train.T
train_features_T
# Out:
#                                   22      108     175     145     71      162  \
# alcohol                         13.71   12.22   13.27   13.16   13.86   12.85
# malic_acid                       1.86    1.29    4.28    3.57    1.51    3.27
# ash                              2.36    1.94    2.26    2.15    2.67    2.58
# alcalinity_of_ash               16.60   19.00   20.00   21.00   25.00   22.00
# magnesium                      101.00   92.00  120.00  102.00   86.00  106.00
# total_phenols                    2.61    2.36    1.59    1.50    2.95    1.65
# flavanoids                       2.88    2.04    0.69    0.55    2.86    0.60
# nonflavanoid_phenols             0.27    0.39    0.43    0.43    0.21    0.60
# proanthocyanins                  1.69    2.08    1.35    1.30    1.87    0.96
# color_intensity                  3.80    2.70   10.20    4.00    3.38    5.58
# hue                              1.11    0.86    0.59    0.60    1.36    0.87
# od280/od315_of_diluted_wines     4.00    3.02    1.56    1.68    3.16    2.11
# proline                       1035.00  312.00  835.00  830.00  410.00  570.00
#
#                                  156      27      83      134  ...      70   \
# alcohol                        13.84    13.30   13.05   12.51  ...   12.290
# malic_acid                      4.12     1.72    3.86    1.24  ...    1.610
# ash                             2.38     2.14    2.32    2.25  ...    2.210
# alcalinity_of_ash              19.50    17.00   22.50   17.50  ...   20.400
# magnesium                      89.00    94.00   85.00   85.00  ...  103.000
# total_phenols                   1.80     2.40    1.65    2.00  ...    1.100
# flavanoids                      0.83     2.19    1.59    0.58  ...    1.020
# nonflavanoid_phenols            0.48     0.27    0.61    0.60  ...    0.370
# proanthocyanins                 1.56     1.35    1.62    1.25  ...    1.460
# color_intensity                 9.01     3.95    4.80    5.45  ...    3.050
# hue                             0.57     1.02    0.84    0.75  ...    0.906
# od280/od315_of_diluted_wines    1.64     2.77    2.01    1.51  ...    1.820
# proline                       480.00  1285.00  515.00  650.00  ...  870.000
#
#                                  87      36      21       9       103     67   \
# alcohol                        11.65   13.28   12.93    13.86   11.82   12.37
# malic_acid                      1.67    1.64    3.80     1.35    1.72    1.17
# ash                             2.62    2.84    2.65     2.27    1.88    1.92
# alcalinity_of_ash              26.00   15.50   18.60    16.00   19.50   19.60
# magnesium                      88.00  110.00  102.00    98.00   86.00   78.00
# total_phenols                   1.92    2.60    2.41     2.98    2.50    2.11
# flavanoids                      1.61    2.68    2.41     3.15    1.64    2.00
# nonflavanoid_phenols            0.40    0.34    0.25     0.22    0.37    0.27
# proanthocyanins                 1.34    1.36    1.98     1.85    1.42    1.04
# color_intensity                 2.60    4.60    4.50     7.22    2.06    4.68
# hue                             1.36    1.09    1.03     1.01    0.94    1.12
# od280/od315_of_diluted_wines    3.21    2.78    3.52     3.55    2.44    3.48
# proline                       562.00  880.00  770.00  1045.00  415.00  510.00
#
#                                  117     47      172
# alcohol                        12.42   13.90   14.16
# malic_acid                      1.61    1.68    2.51
# ash                             2.19    2.12    2.48
# alcalinity_of_ash              22.50   16.00   20.00
# magnesium                     108.00  101.00   91.00
# total_phenols                   2.00    3.10    1.68
# flavanoids                      2.09    3.39    0.70
# nonflavanoid_phenols            0.34    0.21    0.44
# proanthocyanins                 1.61    2.14    1.24
# color_intensity                 2.06    6.10    9.70
# hue                             1.06    0.91    0.62
# od280/od315_of_diluted_wines    2.96    3.33    1.71
# proline                       345.00  985.00  660.00
#
# [13 rows x 124 columns]

# %%
# print the number of duplicated features
print(train_features_T.duplicated().sum())
# Out:
# 0

# %%
# select the duplicated features columns names
duplicated_columns = train_features_T[train_features_T.duplicated()].index.values

# %%
# drop those columns
X_train.drop(labels=duplicated_columns, axis=1, inplace=True)
X_test.drop(labels=duplicated_columns, axis=1, inplace=True)
